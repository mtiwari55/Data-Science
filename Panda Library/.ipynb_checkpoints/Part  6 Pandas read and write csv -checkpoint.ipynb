# %% [markdown]
# # read and write csv and excel file

# %%
import pandas as pd

wheater = pd.read_csv("C:\\Users\\mantiwar\\Desktop\\Pythan-Prac\\weather.csv" )
wheater
# Out:
#           Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   10-05-2018      8.0     24.3       0.0          3.4       6.3          NW
# 1   11-05-2018     14.0     26.9       3.6          4.4       9.7         ENE
# 2   12-05-2018     13.7     23.4       3.6          5.8       3.3          NW
# 3   13-05-2018     13.3     15.5      39.8          7.2       9.1          NW
# 4   14-05-2018      7.6     16.1       2.8          5.6      10.6         SSE
# 5   15-05-2018      6.2     16.9       0.0          5.8       8.2          SE
# 6   16-05-2018      6.1     18.2       0.2          4.2       8.4          SE
# 7   17-05-2018      8.3     17.0       0.0          5.6       4.6           E
# 8   18-05-2018      8.8     19.5       0.0          4.0       4.1           S
# 9   19-05-2018      8.4     22.8      16.2          5.4       7.7           E
# 10  20-05-2018      9.1     25.2       0.0          4.2      11.9           N
# ...

# %%
# select few column

fewWh = wheater[["Date","MinTemp","MaxTemp","Rainfall","Sunshine"]]
aa= fewWh.head(5)
aa
# Out:
#          Date  MinTemp  MaxTemp  Rainfall  Sunshine
# 0  10-05-2018      8.0     24.3       0.0       6.3
# 1  11-05-2018     14.0     26.9       3.6       9.7
# 2  12-05-2018     13.7     23.4       3.6       3.3
# 3  13-05-2018     13.3     15.5      39.8       9.1
# 4  14-05-2018      7.6     16.1       2.8      10.6

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(fewWh["Date"],fewWh["MinTemp"] ,"--")
plt.title("Wheater Report")
plt.xlabel("Date")
plt.ylabel("Temp")
# Out:
# Text(0, 0.5, 'Temp')

# %%
fewWh

# skiprow

# fewWh.skiprowa=1
fewWh.header=1

# %%
x = [1,2,3,4]
y = [1,2,4,4]

plt.plot(x,y)

# %%
fewWh.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall    Sunshine
# count  100.000000  100.000000  100.000000  100.000000
# mean    13.646000   26.323000    2.704000    8.193000
# std      3.089749    5.196052    6.389163    4.071464
# min      6.100000   15.500000    0.000000    0.000000
# 25%     11.775000   22.425000    0.000000    5.900000
# 50%     14.300000   26.300000    0.000000    8.800000
# 75%     15.675000   30.075000    1.850000   11.600000
# max     20.900000   35.800000   39.800000   13.600000

# %%
fewWh.to_csv("delete.csv" ,index=False)

# %%
import pandas as pd


emp = {
    "Name":["A" , "B" ,"C" ,"D"],
    "Id" :[1,2,3,4],
    "Dept" :["IT" ,"ACC" ,"Eng" ,"Fl"]
}


emp

list1 = pd.DataFrame(emp)

list1
# Out:
#   Name  Id Dept
# 0    A   1   IT
# 1    B   2  ACC
# 2    C   3  Eng
# 3    D   4   Fl

# %%
list1.to_csv("newFile.csv" ,columns=["Id","Dept"],index=False)
