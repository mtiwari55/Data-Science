# %%
import pandas as pd
import os

# %%
getPath = os.getcwd()

# %%
getPath
# Out:
# 'C:\\Users\\mantiwar\\Desktop\\Pythan-Prac\\Panda Library'

# %%
files = pd.read_csv(getPath+"\\CityWeather.csv")

# %%
files.head(10 ,inplice =True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-e1e0990caa2b> in <module>
# ----> 1 files.head(10 ,inplice =True)
#
# TypeError: head() got an unexpected keyword argument 'inplice'

# %%
files.columns = files.columns.str.strip()
files.columns
# files.pivot(index="Date" ,columns="City" ,values ="Event")
# Out:
# Index(['Date', 'City', 'Temp', 'Wind', 'Event'], dtype='object')

# %%
files.pivot(index="Temp" ,columns="City")
# Out:
#             Date                                                              \
# City    Bhusawal      Eigat          Goa    Jal gaow      Mumbai      Nashik
# Temp
# 6.0          NaN         NaN         NaN  26-05-2019         NaN         NaN
# 10.0         NaN         NaN         NaN         NaN  25-05-2019         NaN
# 14.0         NaN  27-05-2019         NaN         NaN         NaN         NaN
# 21.0         NaN         NaN         NaN         NaN         NaN         NaN
# 22.0         NaN         NaN         NaN         NaN         NaN  17-05-2019
# 22.6         NaN         NaN         NaN         NaN         NaN         NaN
# 25.7         NaN         NaN         NaN         NaN         NaN         NaN
# 30.4         NaN         NaN         NaN         NaN         NaN         NaN
# 31.0         NaN         NaN         NaN         NaN  20-05-2019         NaN
# 32.0  29-05-2019         NaN         NaN         NaN  10-05-2019         NaN
# ...
