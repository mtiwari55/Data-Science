# %% [markdown]
# # DataFrames 2

# %%
import pandas as pd

weather = {
    "Date":["10-05-2019" ,"11-06-2019","13-05-2019","16-05-2019","21-03-2019","30-05-2019","31-10-2019","22-08-2019"],
    "Event" : ["Rain" ,"Sunny" , "snow" ,"" ,"Rain" ,"Rain","","SunShine" ],
    "Temperature":[24,34,25.5,23,7,20,43,0],
    "Windspace" :[6,7,8,12,0,0,12.5,5]
    
}



whDetails = pd.DataFrame(weather)
whDetails
# Out:
#          Date     Event  Temperature  Windspace
# 0  10-05-2019      Rain         24.0        6.0
# 1  11-06-2019     Sunny         34.0        7.0
# 2  13-05-2019      snow         25.5        8.0
# 3  16-05-2019                   23.0       12.0
# 4  21-03-2019      Rain          7.0        0.0
# 5  30-05-2019      Rain         20.0        0.0
# 6  31-10-2019                   43.0       12.5
# 7  22-08-2019  SunShine          0.0        5.0

# %%
# how will find top 5 reocds

whDetails.head() # return default top 5 records
# Out:
#          Date  Event  Temperature  Windspace
# 0  10-05-2019   Rain         24.0        6.0
# 1  11-06-2019  Sunny         34.0        7.0
# 2  13-05-2019   snow         25.5        8.0
# 3  16-05-2019                23.0       12.0
# 4  21-03-2019   Rain          7.0        0.0

# %%
whDetails.head(4)
# Out:
#          Date  Event  Temperature  Windspace
# 0  10-05-2019   Rain         24.0        6.0
# 1  11-06-2019  Sunny         34.0        7.0
# 2  13-05-2019   snow         25.5        8.0
# 3  16-05-2019                23.0       12.0

# %%
# how will find top 5 bottom records

whDetails.tail()
# Out:
#          Date     Event  Temperature  Windspace
# 3  16-05-2019                   23.0       12.0
# 4  21-03-2019      Rain          7.0        0.0
# 5  30-05-2019      Rain         20.0        0.0
# 6  31-10-2019                   43.0       12.5
# 7  22-08-2019  SunShine          0.0        5.0

# %%
# how will find top 3 bottom recods

whDetails.tail(3)
# Out:
#          Date     Event Temperature Windspace
# 5  30-05-2019      Rain          20
# 6  31-10-2019                    43      12.5
# 7  22-08-2019  SunShine                     5

# %%
# how will find columns name

whDetails.columns
# Out:
# Index(['Date', 'Event', 'Temperature', 'Windspace'], dtype='object')

# %%
# How will display selected columns

whDetails[["Date","Event"]]
# Out:
#          Date     Event
# 0  10-05-2019      Rain
# 1  11-06-2019     Sunny
# 2  13-05-2019      snow
# 3  16-05-2019
# 4  21-03-2019      Rain
# 5  30-05-2019      Rain
# 6  31-10-2019
# 7  22-08-2019  SunShine

# %%
# how will find stastastics

whDetails
# Out:
#          Date     Event  Temperature  Windspace
# 0  10-05-2019      Rain         24.0        6.0
# 1  11-06-2019     Sunny         34.0        7.0
# 2  13-05-2019      snow         25.5        8.0
# 3  16-05-2019                   23.0       12.0
# 4  21-03-2019      Rain          7.0        0.0
# 5  30-05-2019      Rain         20.0        0.0
# 6  31-10-2019                   43.0       12.5
# 7  22-08-2019  SunShine          0.0        5.0

# %%
whDetails.mean()
# Out:
# Temperature    22.0625
# Windspace       6.3125
# dtype: float64

# %%
# Describe function return all statastics details

whDetails.describe()
# Out:
#        Temperature  Windspace
# count     8.000000    8.00000
# mean     22.062500    6.31250
# std      13.707239    4.71273
# min       0.000000    0.00000
# 25%      16.750000    3.75000
# 50%      23.500000    6.50000
# 75%      27.625000    9.00000
# max      43.000000   12.50000

# %%
# how will get greater than and less then with entire row

whDetails[whDetails.Temperature >= 16]
# Out:
#          Date  Event  Temperature  Windspace
# 0  10-05-2019   Rain         24.0        6.0
# 1  11-06-2019  Sunny         34.0        7.0
# 2  13-05-2019   snow         25.5        8.0
# 3  16-05-2019                23.0       12.0
# 5  30-05-2019   Rain         20.0        0.0
# 6  31-10-2019                43.0       12.5

# %%
# max temp and min with entire row

whDetails[whDetails.Temperature == whDetails.Temperature.max()]
# Out:
#          Date Event  Temperature  Windspace
# 6  31-10-2019               43.0       12.5

# %%
whDetails[whDetails.Temperature == whDetails.Temperature.min()]
# Out:
#          Date     Event  Temperature  Windspace
# 7  22-08-2019  SunShine          0.0        5.0

# %%
whDetails[["Date","Event"]][whDetails.Temperature == whDetails.Temperature.min()]
# Out:
#          Date     Event
# 7  22-08-2019  SunShine
